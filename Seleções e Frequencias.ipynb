# %% [markdown]
# # Relatorio de Analise IV

# %% [markdown]
# ## Selecões e Frequencias

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
# Selecione somente os imóveis classificados com tipo 'Apartamento'.
selecao = dados['Tipo'] == 'Apartamento'
n1 = dados[selecao]
n1
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento          Higienópolis        1      0       0    48
# 2      Apartamento              Cachambi        2      0       0    50
# 3      Apartamento                Grajaú        2      1       0    70
# 4      Apartamento   Lins de Vasconcelos        3      1       1    90
# ...            ...                   ...      ...    ...     ...   ...
# 16918  Apartamento        Vila Valqueire        2      0       0    52
# 16919  Apartamento                 Méier        2      0       0    70
# 16920  Apartamento           Jacarepaguá        3      1       2    78
# 16921  Apartamento  São Francisco Xavier        2      1       0    48
# 16922  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0       800.0       390.0  20.0     53.33   Apartamento
# ...

# %%
# Selecione somente os imóveis classificados com tipo 'Apartamento'.
selecao = dados['Tipo'] == 'Apartamento'
n1 = dados[selecao].shape[0]
n1
# Out:
# 16923

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'
selecao = (dados['Tipo'] == 'Casa') | (dados['Tipo'] == 'Casa de Condominio') | (dados['Tipo'] == 'Casa de Vila')
n2 = dados[selecao]
n2
# Out:
#                Tipo             Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 16923          Casa    Jardim Botânico        2      0       1   100   7000.0
# 16924          Casa       Campo Grande        4      1       2   400  12000.0
# 16925          Casa              Méier        2      0       0    51   1500.0
# 16926          Casa           Maracanã        8      3       5   259   7000.0
# 16927          Casa            Benfica        1      0       0    33   1200.0
# ...             ...                ...      ...    ...     ...   ...      ...
# 19013  Casa de Vila          Riachuelo        2      0       0    43   1000.0
# 19014  Casa de Vila  Quintino Bocaiúva        2      0       0    58   1000.0
# 19015  Casa de Vila    Todos os Santos        3      1       1    92   1500.0
# 19016  Casa de Vila          Riachuelo        3      0       0    73    850.0
# 19017  Casa de Vila             Pavuna        2      0       0    55    600.0
#
# ...

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'
selecao = (dados['Tipo'] == 'Casa') | (dados['Tipo'] == 'Casa de Condominio') | (dados['Tipo'] == 'Casa de Vila')
n2 = dados[selecao].shape[0]
n2
# Out:
# 1131

# %%
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
# 60 <= Area <= 100
selecao = (dados['Area'] >= 60) & (dados['Area'] <=100)
n3 = dados[selecao]
n3
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# 7      Apartamento      Barra da Tijuca        2      1       1    67  1700.0
# 9      Apartamento               Olaria        3      1       0    68  1000.0
# 10     Apartamento               Tijuca        2      1       0    78  2000.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19249    Quitinete   Pedra de Guaratiba        1      0       0    70   400.0
# 19390    Quitinete             Realengo        1      0       0    60   650.0
# 19482    Quitinete              Ipanema        1      0       0    60  1800.0
# 19706    Quitinete         Higienópolis        1      0       0    96   700.0
# 19753    Quitinete           Copacabana        1      0       0    62  1800.0
#
# ...

# %%
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
# 60 <= Area <= 100
selecao = (dados['Area'] >= 60) & (dados['Area'] <=100)
n3 = dados[selecao].shape[0]
n3
# Out:
# 8362

# %%
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.
selecao = (dados['Quartos'] >= 4) & (dados['Valor'] < 2000)
n4 = dados[selecao]
n4
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 358           Apartamento  Recreio dos Bandeirantes        4      2       2
# 2965          Apartamento              Campo Grande        4      2       1
# 3260          Apartamento  Recreio dos Bandeirantes        4      2       1
# 4878          Apartamento                 Pechincha        4      1       2
# 5690          Apartamento  Recreio dos Bandeirantes        4      2       3
# 5714          Apartamento  Recreio dos Bandeirantes        4      3       2
# 5877          Apartamento  Recreio dos Bandeirantes        4      2       1
# 7568          Apartamento  Recreio dos Bandeirantes        4      2       1
# 8955          Apartamento                      Leme        4      0       1
# 9373          Apartamento  Recreio dos Bandeirantes        4      2       1
# 9967          Apartamento                   Camorim        4      1       1
# ...

# %%
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.
selecao = (dados['Quartos'] >= 4) & (dados['Valor'] < 2000)
n4 = dados[selecao].shape[0]
n4
# Out:
# 36

# %%
print("N° de imoveis classificados com o tipo 'Apartamento' -> {}".format(n1))
print("N° de imoveis classificados com o tipo 'Casa', 'Casa de Apartamento' e 'Casa de Vila' -> {}".format(n2))
print("N° de imoveis com area entre 60 e 100 metros quadrados, incluindo os limetes -> {}".format(n3))
print("N° de imoveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> {}".format(n4))
# Out:
# N° de imoveis classificados com o tipo 'Apartamento' -> 16923
# N° de imoveis classificados com o tipo 'Casa', 'Casa de Apartamento' e 'Casa de Vila' -> 1131
# N° de imoveis com area entre 60 e 100 metros quadrados, incluindo os limetes -> 8362
# N° de imoveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> 36
